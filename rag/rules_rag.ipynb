# %%
import os
import base64
from byaldi import RAGMultiModalModel
# Out:
# The kernel failed to start as the Python Environment 'DnD (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2", verbose=1)

RAG.index(
    inputh_path = "./basic-rules-fr.pdf",
    index_name="attention",
    store_collection_with_index=True,
    overwrite=True
)
